# %% [markdown]
# ### Data Source 1: Dietary Label Supplement Database (NIH)
# - 1,25,446 supplements
# - Minimum 35 good attributes
# - *US based database*

# %%
import json
import os
from tqdm import tqdm

# %%
data = []
dir_path = 'data/DSLD-full-database-JSON'
for file in os.listdir(dir_path):
    with open(f"{dir_path}/{file}", encoding='utf-8') as f:
        data.append(json.load(f))

# %%
data[1]
# Out:
# {'_index': 'dsldnxt',
#  '_type': '_doc',
#  '_id': '10000',
#  '_version': 1,
#  '_seq_no': 1,
#  '_primary_term': 3,
#  'found': True,
#  '_source': {'langualProductType': 'Non-Nutrient/Non-Botanical [A1309]',
#   'entryDate': '2012-06-25',
#   'labelVersion': '2.0',
#   'dsldId': '10000',
#   'statementGroups': [{'groupName': 'Attributes, including intended target group(s)',
#     'statements': ['Adult (18 - 50 Years)', 'Dairy Free']},
#    {'groupName': 'FDA Disclaimer Statement', 'statements': ['NP']},
#    {'groupName': 'FDA Statement of Identity',
#     'statements': ['A Dietary Supplement']},
#    {'groupName': 'Formulation',
#     'statements': ['This product contains NO yeast, wheat gluten, soy protein, milk/dairy, corn, sodium, starch, artificial coloring, preservatives or flavoring.']},
#    {'groupName': 'Other', 'statements': ['Formula #81322']},
#    {'groupName': 'Precautions',
#     'statements': ['If you are pregnant, nursing, taking any prescription medication (especially hormone replacement therapy), or have an autoimmune or depressive disorder consult a physician before using this product.',
#      'Long-term use of melatonin has not been studied. Use of this product could cause hypothermia. Do not use before or while operating a motor vehicle or heavy machinery.',
#      'Tamper resistant package, do not use if outer seal is missing.',
#      'KEEP OUT OF REACH OF CHILDREN.',
#      'Warning:\nNot to be taken by individuals under the age of 18.']},
#    {'groupName': 'Product Specific Information',
#     'statements': ['For optimal storage conditions, store in a cool, dry place. (59(0)-77(0)F/15(0)-25(0)C) (35-65% relative humidity)']},
#    {'groupName': 'Suggested/Recommended/Usage/Directions',
#     'statements': ['Suggested Usage:\nAs a dietary supplement, adults take 1 sublingual tablet 1 hour before bedtime as directed by physician only. (May be taken sublingually by allowing tablet to dissolve in mouth or with water or juice.)']}],
#   'ipSymbol': '®',
#   'productName': 'Douglas Laboratories Melatonin 3 mg Sublingual Tablets',
#   'langualClaimsOrUses': 'Other Ingredient- Or Constituent-Related Claim Or Use [P0115]',
#   'dietarySupplementsFacts': [{'driFootNotes': '. ND = Not determinable due to lack of data of adverse effects in this age group and concern with regard to lack of ability to handle excess amounts. Source of intake should be from food only to prevent high levels of intake.',
#     'otherTargetGroups': 'Adult (18 - 50 Years); Dairy Free',
#     'servingsPerContainer': '30',
#     'labelFootNotes': 'NP',
#     'dailyValueTargetGroups': 'Adults and children 4 or more years of age',
#     'targetGroupId': '3970',
#     'ingredients': [{'childInfo': [],
#       'data': {'sfbRowDriSourceChildEntryId': '17359',
#        'ingredientEntryName': 'Melatonin',
#        'ingredientEntryClassifier': None,
#        'blendAncestry': None,
#        'labelOffMarket': '0',
#        'sfbRowLabelId': '10000',
#        'numParents': '0',
#        'sfbRowSfbId': '173360',
#        'sfbRowDriSourcePrefix': None,
#        'sfbQuantityColumnSfbQuantityColumnId': '19836',
#        'ingredientEntrySourceIngredientEntryName': 'Melatonin',
#        'unitUnitId': '3955',
#        'sfbRowSfbRowNumber': '1',
#        'relationalOperatorOperatorSymbol': '=',
#        'sfbRowDriSourceParentEntryId': '17359',
#        'ingredientEntrySubspecies': None,
#        'ingredientEntryGrpId': '517',
#        'rowNum': '1',
#        'sfbQuantityColumnSfbColumnNumber': '1',
#        'sfbRowParentSfbRowId': None,
#        'dvTargetGroupDvGroupName': 'Adults and children 4 or more years of age',
#        'sfbQuantityColumnColumnLabel': 'Amount Per Serving',
#        'sfbRowIdAncestry': '0',
#        'relationalOperatorOperatorId': None,
#        'sfbQuantityQuantity': '3.0',
#        'sfbRowDriSourcePercent': None,
#        'unitName': 'mg',
#        'sfbRowDriSourceChildDriId': '0',
#        'sfbDvPercent': None,
#        'labelFullName': 'Melatonin 3 mg Sublingual Tablets',
#        'relationalOperatorOpsym': None,
#        'sfbDvFootnoteFootnoteText': 'Daily Value not established',
#        'ingredientEntryPlantPart': None,
#        'ingredientEntryNotes': None,
#        'sfbRowDriSourceRootEntryId': '17359',
#        'sfbDvDvTargetGroupId': '3970',
#        'ingredientEntryGenus': None,
#        'ingredientEntryIngredientEntryId': '17359',
#        'ingredientEntryCategory': 'hormone',
#        'sfbRowDriSourceLvl': '0',
#        'ingredientEntrySpecies': None,
#        'ingredientEntryIpSymbolId': '3977',
#        'sfbRowDriSourcePosition': '1'},
#       'dvPercent': None,
#       'groupId': '517',
#       'hierarchyIngredient': [],
#       'name': 'Melatonin',
#       'dvOperator': None,
#       'altName': '',
#       'dvFactor': 1.0}],
#     'servingSizeUnitName': 'Tablet(s)',
#     'servingSizeQuantity': '1.0',
#     'otheringredients': {'text': 'Cellulose, Fructose, Silica, Vegetable Stearate',
#      'type': 'Other Ingredients:'},
#     'targetGroupName': 'Adults and children 4 or more years of age',
#     'usageSuggestion': {'text': 'Suggested Usage:\nAs a dietary supplement, adults take 1 sublingual tablet 1 hour before bedtime as directed by physician only. (May be taken sublingually by allowing tablet to dissolve in mouth or with water or juice.)',
#      'type': 'Suggested/ Recommended/ Usage/ Directions'}}],
#   'langualCodes': {'targetGroup': ['P0250'],
#    'claimsOrUses': ['P0115'],
#    'supplementForm': ['E0155'],
#    'productType': ['A1309']},
#   'langualTargetGroup': 'Four years and above [P0250]',
#   'statementOfIdentity': 'A Dietary Supplement',
#   'netContentQuantities': '30.0 Tablet(s)\r\n',
#   'offMarket': '0',
#   'langualSupplementForm': 'Tablet (will cover pill) [E0155]',
#   'sku': '3 10539 01866 8',
#   'nhanesId': '',
#   'brand': 'Douglas Laboratories',
#   'outerPackaging': 'Not Present',
#   'servingSize': [{'size': '1.0 Tablet(s)', 'type': 'Serving Size'}],
#   'events': [{'date': 'June 25, 2012', 'name': 'Date - Entered into DSLD'}],
#   'contacts': [{'zip': '15205',
#     'country': None,
#     'isDistributor': 'no',
#     'contactId': '2647',
#     'city': 'Pittsburgh',
#     'webAddress': 'www.douglaslabs.com',
#     'isManufacturer': 'yes',
#     'contactType': 'Manufactured by',
#     'isPackager': 'no',
#     'isReseller': 'no',
#     'phoneNumber': None,
#     'streetAddress': None,
#     'name': 'Douglas Laboratories',
#     'state': 'PA',
#     'isOther': 'no',
#     'email': None}],
#   'suggestedUse': 'Suggested Usage:\nAs a dietary supplement, adults take 1 sublingual tablet 1 hour before bedtime as directed by physician only. (May be taken sublingually by allowing tablet to dissolve in mouth or with water or juice.)\r\n'}}

# %%
len(data)
# Out:
# 125446

# %%
for key in data[1]['_source']:
    print(key)
# Out:
# langualProductType
# entryDate
# labelVersion
# dsldId
# statementGroups
# ipSymbol
# productName
# langualClaimsOrUses
# dietarySupplementsFacts
# langualCodes
# langualTargetGroup
# statementOfIdentity
# netContentQuantities
# offMarket
# langualSupplementForm
# sku
# nhanesId
# brand
# outerPackaging
# servingSize
# events
# contacts
# suggestedUse

# %%
def format_json(data):
    formatted_data = {}

    # Primary Values
    formatted_data['id'] = data['_id']
    for key in data['_source']:
        if key in {'langualProductType', 'entryDate', 'langualTargetGroup', 'statementOfIdentity', 'netContentQuantities', 'langualSupplementForm', 'servingSize', 'events', 'suggestedUse'}:
            formatted_data[key] = data['_source'][key][0]['size'] if key == 'servingSize' else data['_source'][key]
    try:
        formatted_data['productType'] = data['_source']['langualProductType']
        formatted_data['entryDate'] = data['_source']['entryDate']
    except:
        pass

    # Statement Groups
    for group in data['_source']['statementGroups']:
        formatted_data[group['groupName']] = group['statements']
    
    # Supplement Facts
    try:
        formatted_data['productName'] = data['_source']['productName']    
        for key in data['_source']['dietarySupplementsFacts'][0]:
            if key in ['targetGroupId', 'ingredients']:
                continue
            if key == 'otheringredients':
                formatted_data[key] = data['_source']['dietarySupplementsFacts'][0][key]['text']
            else:
                formatted_data[key] = data['_source']['dietarySupplementsFacts'][0][key]
    except:
        pass
    
    # Ingredients
    try:
        for key in data['_source']['dietarySupplementsFacts'][0]['ingredients'][0]['data']:
            if key in ['ingredientEntryName', 'dvTargetGroupDvGroupName', 'sfbQuantityColumnColumnLabel', 'sfbQuantityQuantity', 'unitName', 'labelFullName', 'sfbDvFootnoteFootnoteText', 'ingredientEntryPlantPart', 'ingredientEntryCategory']:
                formatted_data[key] = data['_source']['dietarySupplementsFacts'][0]['ingredients'][0]['data'][key]
    except:
        pass
    
    try:
        for key in data['_source']['dietarySupplementsFacts'][0]['ingredients'][0]:
            if key in ['hierarchyIngredient', 'altName']:
                formatted_data[key] = data['_source']['dietarySupplementsFacts'][0]['ingredients'][0][key]
    except:
        pass

    return formatted_data

# %%
sample = format_json(data[1])
print(list(sample.keys()))
# Out:
# ['id', 'langualProductType', 'entryDate', 'langualTargetGroup', 'statementOfIdentity', 'netContentQuantities', 'langualSupplementForm', 'servingSize', 'events', 'suggestedUse', 'productType', 'Attributes, including intended target group(s)', 'FDA Disclaimer Statement', 'FDA Statement of Identity', 'Formulation', 'Other', 'Precautions', 'Product Specific Information', 'Suggested/Recommended/Usage/Directions', 'productName', 'driFootNotes', 'otherTargetGroups', 'servingsPerContainer', 'labelFootNotes', 'dailyValueTargetGroups', 'servingSizeUnitName', 'servingSizeQuantity', 'otheringredients', 'targetGroupName', 'usageSuggestion', 'ingredientEntryName', 'dvTargetGroupDvGroupName', 'sfbQuantityColumnColumnLabel', 'sfbQuantityQuantity', 'unitName', 'labelFullName', 'sfbDvFootnoteFootnoteText', 'ingredientEntryPlantPart', 'ingredientEntryCategory', 'hierarchyIngredient', 'altName']

# %%
processed = []
for i in tqdm(range(len(data))):
    processed.append(format_json(data[i]))
# Out:
# 100%|██████████| 125446/125446 [00:09<00:00, 12901.80it/s]

# %%
n = 5
sample = processed[:n]
for i in range(n):
    print(f"Product: {sample[i]['labelFullName']}, Type: {sample[i]['langualProductType']}")
# Out:
# Product: Coral Calcium, Type: Dietary Supplements, Combination, Other [A1325]
# Product: Melatonin 3 mg Sublingual Tablets, Type: Non-Nutrient/Non-Botanical [A1309]
# Product: Melatonin 3 mg, Type: Non-Nutrient/Non-Botanical [A1309]
# Product: Melatonin 3 mg Sublingual Tablets, Type: Non-Nutrient/Non-Botanical [A1309]
# Product: Melatonin 3 mg Sublingual Tablets, Type: Non-Nutrient/Non-Botanical [A1309]

# %%
sample = processed[:100]
sample[0]
# Out:
# {'id': '1000',
#  'langualProductType': 'Dietary Supplements, Combination, Other [A1325]',
#  'entryDate': '2011-10-26',
#  'langualTargetGroup': 'Four years and above [P0250]',
#  'statementOfIdentity': 'DIETARY SUPPLEMENT',
#  'netContentQuantities': '60.0 Capsule(s)\r\n',
#  'langualSupplementForm': 'Capsule [E0159]',
#  'servingSize': '2.0 Capsule(s)',
#  'events': [{'date': 'October 26, 2011', 'name': 'Date - Entered into DSLD'}],
#  'suggestedUse': 'Directions: As a dietary supplement, take two capsules daily.\r\n',
#  'productType': 'Dietary Supplements, Combination, Other [A1325]',
#  'Attributes, including intended target group(s)': ['Adult (18 - 50 Years)'],
#  'FDA Disclaimer Statement': ['NP'],
#  'FDA Statement of Identity': ['DIETARY SUPPLEMENT'],
#  'Formulation': ['optimal 2:1 ratio of calcium and magnesium'],
#  'Other': ['ACTUAL SIZE',
#   'GNC Coral Calcium naturally supplies calcium, magnesium and numerous other essential trace minerals. Gathered from fossilized coral from above the Okinawan sea, our coral is environmentally friendly. This harvesting process protects the delicate ecology of the sea and allows living reefs and algae to continue to thrive.',
#   'Lot No./Best By:',
#   'Made in the USA',
#   'MARINE SOURCE',
#   'source of trace minerals',
#   'CODE 553711 GGG'],
#  'Precautions': ['KEEP OUT OF REACH OF CHILDREN.'],
#  'Product Specific Information': ['Store in a cool, dry place.'],
#  'Suggested/Recommended/Usage/Directions': ['Directions: As a dietary supplement, take two capsules daily.'],
#  'productName': 'GNC Coral Calcium',
#  'driFootNotes': '. ND = Not determinable due to lack of data of adverse effects in this age group and concern with regard to lack of ability to handle excess amounts. Source of intake should be from food only to prevent high levels of intake.\r\n2. The ULs for magnesium represent intake from a pharmacological agent only and do not include intake from food and water.',
#  'otherTargetGroups': 'Adult (18 - 50 Years)',
#  'servingsPerContainer': '30',
#  'labelFootNotes': 'NP',
#  'dailyValueTargetGroups': 'Adults and children 4 or more years of age',
#  'servingSizeUnitName': 'Capsule(s)',
#  'servingSizeQuantity': '2.0',
#  'otheringredients': 'Gelatin, Titanium Dioxide (natural mineral whitener)',
#  'targetGroupName': 'Adults and children 4 or more years of age',
#  'usageSuggestion': {'text': 'Directions: As a dietary supplement, take two capsules daily.',
#   'type': 'Suggested/ Recommended/ Usage/ Directions'},
#  'ingredientEntryName': 'Vitamin D',
#  'dvTargetGroupDvGroupName': 'Adults and children 4 or more years of age',
#  'sfbQuantityColumnColumnLabel': 'Amount Per Serving',
#  'sfbQuantityQuantity': '200.0',
#  'unitName': 'IU',
#  'labelFullName': 'Coral Calcium',
#  'sfbDvFootnoteFootnoteText': None,
#  'ingredientEntryPlantPart': None,
#  'ingredientEntryCategory': 'vitamin',
#  'hierarchyIngredient': [],
#  'altName': ''}

# %%
import pickle

with open('supplements_data.pkl', 'wb') as f:
    pickle.dump(processed, f)

# %%
with open('supplements_data.json', 'w') as f:
    json.dump(processed, f)

# %%
processed[0]
# Out:
# {'id': '1000',
#  'langualProductType': 'Dietary Supplements, Combination, Other [A1325]',
#  'entryDate': '2011-10-26',
#  'langualTargetGroup': 'Four years and above [P0250]',
#  'statementOfIdentity': 'DIETARY SUPPLEMENT',
#  'netContentQuantities': '60.0 Capsule(s)\r\n',
#  'langualSupplementForm': 'Capsule [E0159]',
#  'servingSize': '2.0 Capsule(s)',
#  'events': [{'date': 'October 26, 2011', 'name': 'Date - Entered into DSLD'}],
#  'suggestedUse': 'Directions: As a dietary supplement, take two capsules daily.\r\n',
#  'productType': 'Dietary Supplements, Combination, Other [A1325]',
#  'Attributes, including intended target group(s)': ['Adult (18 - 50 Years)'],
#  'FDA Disclaimer Statement': ['NP'],
#  'FDA Statement of Identity': ['DIETARY SUPPLEMENT'],
#  'Formulation': ['optimal 2:1 ratio of calcium and magnesium'],
#  'Other': ['ACTUAL SIZE',
#   'GNC Coral Calcium naturally supplies calcium, magnesium and numerous other essential trace minerals. Gathered from fossilized coral from above the Okinawan sea, our coral is environmentally friendly. This harvesting process protects the delicate ecology of the sea and allows living reefs and algae to continue to thrive.',
#   'Lot No./Best By:',
#   'Made in the USA',
#   'MARINE SOURCE',
#   'source of trace minerals',
#   'CODE 553711 GGG'],
#  'Precautions': ['KEEP OUT OF REACH OF CHILDREN.'],
#  'Product Specific Information': ['Store in a cool, dry place.'],
#  'Suggested/Recommended/Usage/Directions': ['Directions: As a dietary supplement, take two capsules daily.'],
#  'productName': 'GNC Coral Calcium',
#  'driFootNotes': '. ND = Not determinable due to lack of data of adverse effects in this age group and concern with regard to lack of ability to handle excess amounts. Source of intake should be from food only to prevent high levels of intake.\r\n2. The ULs for magnesium represent intake from a pharmacological agent only and do not include intake from food and water.',
#  'otherTargetGroups': 'Adult (18 - 50 Years)',
#  'servingsPerContainer': '30',
#  'labelFootNotes': 'NP',
#  'dailyValueTargetGroups': 'Adults and children 4 or more years of age',
#  'servingSizeUnitName': 'Capsule(s)',
#  'servingSizeQuantity': '2.0',
#  'otheringredients': 'Gelatin, Titanium Dioxide (natural mineral whitener)',
#  'targetGroupName': 'Adults and children 4 or more years of age',
#  'usageSuggestion': {'text': 'Directions: As a dietary supplement, take two capsules daily.',
#   'type': 'Suggested/ Recommended/ Usage/ Directions'},
#  'ingredientEntryName': 'Vitamin D',
#  'dvTargetGroupDvGroupName': 'Adults and children 4 or more years of age',
#  'sfbQuantityColumnColumnLabel': 'Amount Per Serving',
#  'sfbQuantityQuantity': '200.0',
#  'unitName': 'IU',
#  'labelFullName': 'Coral Calcium',
#  'sfbDvFootnoteFootnoteText': None,
#  'ingredientEntryPlantPart': None,
#  'ingredientEntryCategory': 'vitamin',
#  'hierarchyIngredient': [],
#  'altName': ''}

# %% [markdown]
# ## Data
# - Merging similar instances of different supplements
# - TRC, medlinePlus (National Library of Medicine)
# - Complementary and Alterenative Medicies (for natural, regional supplements)

# %%
import json
# with open('supplements_data.json') as f:
#     data = json.load(f)

# len(data)

# %%
data[:5]
# Out:
# [{'id': '1000',
#   'langualProductType': 'Dietary Supplements, Combination, Other [A1325]',
#   'entryDate': '2011-10-26',
#   'langualTargetGroup': 'Four years and above [P0250]',
#   'statementOfIdentity': 'DIETARY SUPPLEMENT',
#   'netContentQuantities': '60.0 Capsule(s)\r\n',
#   'langualSupplementForm': 'Capsule [E0159]',
#   'servingSize': '2.0 Capsule(s)',
#   'events': [{'date': 'October 26, 2011', 'name': 'Date - Entered into DSLD'}],
#   'suggestedUse': 'Directions: As a dietary supplement, take two capsules daily.\r\n',
#   'productType': 'Dietary Supplements, Combination, Other [A1325]',
#   'Attributes, including intended target group(s)': ['Adult (18 - 50 Years)'],
#   'FDA Disclaimer Statement': ['NP'],
#   'FDA Statement of Identity': ['DIETARY SUPPLEMENT'],
#   'Formulation': ['optimal 2:1 ratio of calcium and magnesium'],
#   'Other': ['ACTUAL SIZE',
#    'GNC Coral Calcium naturally supplies calcium, magnesium and numerous other essential trace minerals. Gathered from fossilized coral from above the Okinawan sea, our coral is environmentally friendly. This harvesting process protects the delicate ecology of the sea and allows living reefs and algae to continue to thrive.',
#    'Lot No./Best By:',
#    'Made in the USA',
#    'MARINE SOURCE',
#    'source of trace minerals',
#    'CODE 553711 GGG'],
#   'Precautions': ['KEEP OUT OF REACH OF CHILDREN.'],
#   'Product Specific Information': ['Store in a cool, dry place.'],
#   'Suggested/Recommended/Usage/Directions': ['Directions: As a dietary supplement, take two capsules daily.'],
#   'productName': 'GNC Coral Calcium',
#   'driFootNotes': '. ND = Not determinable due to lack of data of adverse effects in this age group and concern with regard to lack of ability to handle excess amounts. Source of intake should be from food only to prevent high levels of intake.\r\n2. The ULs for magnesium represent intake from a pharmacological agent only and do not include intake from food and water.',
#   'otherTargetGroups': 'Adult (18 - 50 Years)',
#   'servingsPerContainer': '30',
#   'labelFootNotes': 'NP',
#   'dailyValueTargetGroups': 'Adults and children 4 or more years of age',
#   'servingSizeUnitName': 'Capsule(s)',
#   'servingSizeQuantity': '2.0',
#   'otheringredients': 'Gelatin, Titanium Dioxide (natural mineral whitener)',
#   'targetGroupName': 'Adults and children 4 or more years of age',
#   'usageSuggestion': {'text': 'Directions: As a dietary supplement, take two capsules daily.',
#    'type': 'Suggested/ Recommended/ Usage/ Directions'},
#   'ingredientEntryName': 'Vitamin D',
#   'dvTargetGroupDvGroupName': 'Adults and children 4 or more years of age',
#   'sfbQuantityColumnColumnLabel': 'Amount Per Serving',
#   'sfbQuantityQuantity': '200.0',
#   'unitName': 'IU',
#   'labelFullName': 'Coral Calcium',
#   'sfbDvFootnoteFootnoteText': None,
#   'ingredientEntryPlantPart': None,
#   'ingredientEntryCategory': 'vitamin',
#   'hierarchyIngredient': [],
#   'altName': ''},
#  {'id': '10000',
#   'langualProductType': 'Non-Nutrient/Non-Botanical [A1309]',
#   'entryDate': '2012-06-25',
#   'langualTargetGroup': 'Four years and above [P0250]',
#   'statementOfIdentity': 'A Dietary Supplement',
#   'netContentQuantities': '30.0 Tablet(s)\r\n',
#   'langualSupplementForm': 'Tablet (will cover pill) [E0155]',
#   'servingSize': '1.0 Tablet(s)',
#   'events': [{'date': 'June 25, 2012', 'name': 'Date - Entered into DSLD'}],
#   'suggestedUse': 'Suggested Usage:\nAs a dietary supplement, adults take 1 sublingual tablet 1 hour before bedtime as directed by physician only. (May be taken sublingually by allowing tablet to dissolve in mouth or with water or juice.)\r\n',
#   'productType': 'Non-Nutrient/Non-Botanical [A1309]',
#   'Attributes, including intended target group(s)': ['Adult (18 - 50 Years)',
#    'Dairy Free'],
#   'FDA Disclaimer Statement': ['NP'],
#   'FDA Statement of Identity': ['A Dietary Supplement'],
#   'Formulation': ['This product contains NO yeast, wheat gluten, soy protein, milk/dairy, corn, sodium, starch, artificial coloring, preservatives or flavoring.'],
#   'Other': ['Formula #81322'],
#   'Precautions': ['If you are pregnant, nursing, taking any prescription medication (especially hormone replacement therapy), or have an autoimmune or depressive disorder consult a physician before using this product.',
#    'Long-term use of melatonin has not been studied. Use of this product could cause hypothermia. Do not use before or while operating a motor vehicle or heavy machinery.',
#    'Tamper resistant package, do not use if outer seal is missing.',
#    'KEEP OUT OF REACH OF CHILDREN.',
#    'Warning:\nNot to be taken by individuals under the age of 18.'],
#   'Product Specific Information': ['For optimal storage conditions, store in a cool, dry place. (59(0)-77(0)F/15(0)-25(0)C) (35-65% relative humidity)'],
#   'Suggested/Recommended/Usage/Directions': ['Suggested Usage:\nAs a dietary supplement, adults take 1 sublingual tablet 1 hour before bedtime as directed by physician only. (May be taken sublingually by allowing tablet to dissolve in mouth or with water or juice.)'],
#   'productName': 'Douglas Laboratories Melatonin 3 mg Sublingual Tablets',
#   'driFootNotes': '. ND = Not determinable due to lack of data of adverse effects in this age group and concern with regard to lack of ability to handle excess amounts. Source of intake should be from food only to prevent high levels of intake.',
#   'otherTargetGroups': 'Adult (18 - 50 Years); Dairy Free',
#   'servingsPerContainer': '30',
#   'labelFootNotes': 'NP',
#   'dailyValueTargetGroups': 'Adults and children 4 or more years of age',
#   'servingSizeUnitName': 'Tablet(s)',
#   'servingSizeQuantity': '1.0',
#   'otheringredients': 'Cellulose, Fructose, Silica, Vegetable Stearate',
#   'targetGroupName': 'Adults and children 4 or more years of age',
#   'usageSuggestion': {'text': 'Suggested Usage:\nAs a dietary supplement, adults take 1 sublingual tablet 1 hour before bedtime as directed by physician only. (May be taken sublingually by allowing tablet to dissolve in mouth or with water or juice.)',
#    'type': 'Suggested/ Recommended/ Usage/ Directions'},
#   'ingredientEntryName': 'Melatonin',
#   'dvTargetGroupDvGroupName': 'Adults and children 4 or more years of age',
#   'sfbQuantityColumnColumnLabel': 'Amount Per Serving',
#   'sfbQuantityQuantity': '3.0',
#   'unitName': 'mg',
#   'labelFullName': 'Melatonin 3 mg Sublingual Tablets',
#   'sfbDvFootnoteFootnoteText': 'Daily Value not established',
#   'ingredientEntryPlantPart': None,
#   'ingredientEntryCategory': 'hormone',
#   'hierarchyIngredient': [],
#   'altName': ''},
#  {'id': '10001',
#   'langualProductType': 'Non-Nutrient/Non-Botanical [A1309]',
#   'entryDate': '2012-06-25',
#   'langualTargetGroup': 'Four years and above [P0250]',
#   'statementOfIdentity': 'A Dietary Supplement',
#   'netContentQuantities': '60.0 Tablet(s)\r\n',
#   'langualSupplementForm': 'Tablet (will cover pill) [E0155]',
#   'servingSize': '1.0 Tablet(s)',
#   'events': [{'date': 'June 25, 2012', 'name': 'Date - Entered into DSLD'},
#    {'date': 'December 15, 2015', 'name': 'Date - Off Market'}],
#   'suggestedUse': 'Suggested Usage: As a dietary supplement, adults take 1 tablet 30 minutes before bedtime or as directed by your healthcare professional only. Allow tablet to dissolve in mouth or with water or juice and then swallow.\r\n',
#   'productType': 'Non-Nutrient/Non-Botanical [A1309]',
#   'Attributes, including intended target group(s)': ['Dairy Free',
#    'Adult (18 - 50 Years)'],
#   'FDA Disclaimer Statement': ['NP'],
#   'FDA Statement of Identity': ['A Dietary Supplement'],
#   'Formulation': ['This product contains NO yeast, wheat, gluten, soy protein, milk/dairy, corn, sodium, starch, artificial coloring, preservatives or flavoring.'],
#   'Other': ['Formula #81322'],
#   'Precautions': ['Tamper resistant package, do not use if outer seal is missing.',
#    'Warning: Not to be taken by individuals under the age of 18. If you are pregnant, nursing, taking any prescription medication (especially hormone replacement therapy), or have an autoimmune or depressive disorder consult your healthcare professional before using this product. Long-term use of melatonin has not been studied. Use of this product could cause hypothermia. Do not use before or while operating a motor vehicle or heavy machinery.',
#    'KEEP OUT OF REACH OF CHILDREN.'],
#   'Product Specific Information': ['For optimal storage conditions, store in a cool, dry place. (59(0)-77(0)F/15(0)-25(0)C) (35-65% relative humidity)'],
#   'Suggested/Recommended/Usage/Directions': ['Suggested Usage: As a dietary supplement, adults take 1 tablet 30 minutes before bedtime or as directed by your healthcare professional only. Allow tablet to dissolve in mouth or with water or juice and then swallow.'],
#   'productName': 'Douglas Laboratories Melatonin 3 mg',
#   'driFootNotes': '. ND = Not determinable due to lack of data of adverse effects in this age group and concern with regard to lack of ability to handle excess amounts. Source of intake should be from food only to prevent high levels of intake.',
#   'otherTargetGroups': 'Dairy Free; Adult (18 - 50 Years)',
#   'servingsPerContainer': '60',
#   'labelFootNotes': 'NP',
#   'dailyValueTargetGroups': 'Adults and children 4 or more years of age',
#   'servingSizeUnitName': 'Tablet(s)',
#   'servingSizeQuantity': '1.0',
#   'otheringredients': 'Cellulose, Fructose, Dicalcium Phosphate, Vegetable Stearate',
#   'targetGroupName': 'Adults and children 4 or more years of age',
#   'usageSuggestion': {'text': 'Suggested Usage: As a dietary supplement, adults take 1 tablet 30 minutes before bedtime or as directed by your healthcare professional only. Allow tablet to dissolve in mouth or with water or juice and then swallow.',
#    'type': 'Suggested/ Recommended/ Usage/ Directions'},
#   'ingredientEntryName': 'Melatonin',
#   'dvTargetGroupDvGroupName': 'Adults and children 4 or more years of age',
#   'sfbQuantityColumnColumnLabel': 'Amount Per Serving',
#   'sfbQuantityQuantity': '3.0',
#   'unitName': 'mg',
#   'labelFullName': 'Melatonin 3 mg',
#   'sfbDvFootnoteFootnoteText': 'Daily Value not established',
#   'ingredientEntryPlantPart': None,
#   'ingredientEntryCategory': 'hormone',
#   'hierarchyIngredient': [],
#   'altName': ''},
#  {'id': '10002',
#   'langualProductType': 'Non-Nutrient/Non-Botanical [A1309]',
#   'entryDate': '2012-06-25',
#   'langualTargetGroup': 'Four years and above [P0250]',
#   'statementOfIdentity': 'A Dietary Supplement',
#   'netContentQuantities': '120.0 Tablet(s)\r\n',
#   'langualSupplementForm': 'Tablet (will cover pill) [E0155]',
#   'servingSize': '1.0 Tablet(s)',
#   'events': [{'date': 'June 25, 2012', 'name': 'Date - Entered into DSLD'}],
#   'suggestedUse': 'Suggested Usage:\nAs a dietary supplement, adults take 1 sublingual tablet 1 hour before bedtime as directed by physician only. (May be taken sublingually by allowing tablet to dissolve in mouth or with water or juice.)\r\n',
#   'productType': 'Non-Nutrient/Non-Botanical [A1309]',
#   'Attributes, including intended target group(s)': ['Adult (18 - 50 Years)',
#    'Dairy Free'],
#   'FDA Disclaimer Statement': ['NP'],
#   'FDA Statement of Identity': ['A Dietary Supplement'],
#   'Formulation': ['This product contains NO yeast, wheat gluten, soy protein, milk/dairy, corn, sodium, starch, artificial coloring, preservatives or flavoring.'],
#   'Other': ['Formula #81322'],
#   'Precautions': ['If you are pregnant, nursing, taking any prescription medication (especially hormone replacement therapy), or have an autoimmune or depressive disorder consult a physician before using this product.',
#    'Long-term use of melatonin has not been studied. Use of this product could cause hypothermia. Do not use before or while operating a motor vehicle or heavy machinery.',
#    'Tamper resistant package, do not use if outer seal is missing.',
#    'KEEP OUT OF REACH OF CHILDREN.',
#    'Warning:\nNot to be taken by individuals under the age of 18.'],
#   'Product Specific Information': ['For optimal storage conditions, store in a cool, dry place. (59(0)-77(0)F/15(0)-25(0)C) (35-65% relative humidity)'],
#   'Suggested/Recommended/Usage/Directions': ['Suggested Usage:\nAs a dietary supplement, adults take 1 sublingual tablet 1 hour before bedtime as directed by physician only. (May be taken sublingually by allowing tablet to dissolve in mouth or with water or juice.)'],
#   'productName': 'Douglas Laboratories Melatonin 3 mg Sublingual Tablets',
#   'driFootNotes': '. ND = Not determinable due to lack of data of adverse effects in this age group and concern with regard to lack of ability to handle excess amounts. Source of intake should be from food only to prevent high levels of intake.',
#   'otherTargetGroups': 'Adult (18 - 50 Years); Dairy Free',
#   'servingsPerContainer': '120',
#   'labelFootNotes': 'NP',
#   'dailyValueTargetGroups': 'Adults and children 4 or more years of age',
#   'servingSizeUnitName': 'Tablet(s)',
#   'servingSizeQuantity': '1.0',
#   'otheringredients': 'Cellulose, Sucrose, Silica, Vegetable Stearate',
#   'targetGroupName': 'Adults and children 4 or more years of age',
#   'usageSuggestion': {'text': 'Suggested Usage:\nAs a dietary supplement, adults take 1 sublingual tablet 1 hour before bedtime as directed by physician only. (May be taken sublingually by allowing tablet to dissolve in mouth or with water or juice.)',
#    'type': 'Suggested/ Recommended/ Usage/ Directions'},
#   'ingredientEntryName': 'Melatonin',
#   'dvTargetGroupDvGroupName': 'Adults and children 4 or more years of age',
#   'sfbQuantityColumnColumnLabel': 'Amount Per Serving',
#   'sfbQuantityQuantity': '3.0',
#   'unitName': 'mg',
#   'labelFullName': 'Melatonin 3 mg Sublingual Tablets',
#   'sfbDvFootnoteFootnoteText': 'Daily Value not established',
#   'ingredientEntryPlantPart': None,
#   'ingredientEntryCategory': 'hormone',
#   'hierarchyIngredient': [],
#   'altName': ''},
#  {'id': '10003',
#   'langualProductType': 'Non-Nutrient/Non-Botanical [A1309]',
#   'entryDate': '2012-06-25',
#   'langualTargetGroup': 'Four years and above [P0250]',
#   'statementOfIdentity': 'A Dietary Supplement',
#   'netContentQuantities': '180.0 Tablet(s)\r\n',
#   'langualSupplementForm': 'Tablet (will cover pill) [E0155]',
#   'servingSize': '1.0 Tablet(s)',
#   'events': [{'date': 'June 25, 2012', 'name': 'Date - Entered into DSLD'}],
#   'suggestedUse': 'Suggested Usage:\nAs a dietary supplement, adults take 1 sublingual tablet 1 hour before bedtime as directed by physician only. (May be taken sublingually by allowing tablet to dissolve in mouth or with water or juice.)\r\n',
#   'productType': 'Non-Nutrient/Non-Botanical [A1309]',
#   'Attributes, including intended target group(s)': ['Adult (18 - 50 Years)',
#    'Dairy Free'],
#   'FDA Disclaimer Statement': ['NP'],
#   'FDA Statement of Identity': ['A Dietary Supplement'],
#   'Formulation': ['This product contains NO yeast, wheat gluten, soy protein, milk/dairy, corn, sodium, starch, artificial coloring, preservatives or flavoring.'],
#   'Other': ['Formula #81322'],
#   'Precautions': ['If you are pregnant, nursing, taking any prescription medication (especially hormone replacement therapy), or have an autoimmune or depressive disorder consult a physician before using this product.',
#    'Long-term use of melatonin has not been studied. Use of this product could cause hypothermia. Do not use before or while operating a motor vehicle or heavy machinery.',
#    'Tamper resistant package, do not use if outer seal is missing.',
#    'KEEP OUT OF REACH OF CHILDREN.',
#    'Warning:\nNot to be taken by individuals under the age of 18.'],
#   'Product Specific Information': ['For optimal storage conditions, store in a cool, dry place. (59(0)-77(0)F/15(0)-25(0)C) (35-65% relative humidity)'],
#   'Suggested/Recommended/Usage/Directions': ['Suggested Usage:\nAs a dietary supplement, adults take 1 sublingual tablet 1 hour before bedtime as directed by physician only. (May be taken sublingually by allowing tablet to dissolve in mouth or with water or juice.)'],
#   'productName': 'Douglas Laboratories Melatonin 3 mg Sublingual Tablets',
#   'driFootNotes': '. ND = Not determinable due to lack of data of adverse effects in this age group and concern with regard to lack of ability to handle excess amounts. Source of intake should be from food only to prevent high levels of intake.',
#   'otherTargetGroups': 'Adult (18 - 50 Years); Dairy Free',
#   'servingsPerContainer': '180',
#   'labelFootNotes': 'NP',
#   'dailyValueTargetGroups': 'Adults and children 4 or more years of age',
#   'servingSizeUnitName': 'Tablet(s)',
#   'servingSizeQuantity': '1.0',
#   'otheringredients': 'Cellulose, Sucrose, Silica, Vegetable Stearate',
#   'targetGroupName': 'Adults and children 4 or more years of age',
#   'usageSuggestion': {'text': 'Suggested Usage:\nAs a dietary supplement, adults take 1 sublingual tablet 1 hour before bedtime as directed by physician only. (May be taken sublingually by allowing tablet to dissolve in mouth or with water or juice.)',
#    'type': 'Suggested/ Recommended/ Usage/ Directions'},
#   'ingredientEntryName': 'Melatonin',
#   'dvTargetGroupDvGroupName': 'Adults and children 4 or more years of age',
#   'sfbQuantityColumnColumnLabel': 'Amount Per Serving',
#   'sfbQuantityQuantity': '3.0',
#   'unitName': 'mg',
#   'labelFullName': 'Melatonin 3 mg Sublingual Tablets',
#   'sfbDvFootnoteFootnoteText': 'Daily Value not established',
#   'ingredientEntryPlantPart': None,
#   'ingredientEntryCategory': 'hormone',
#   'hierarchyIngredient': [],
#   'altName': ''}]
